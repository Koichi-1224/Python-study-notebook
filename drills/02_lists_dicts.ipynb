# %% [markdown]
# # ドリル2：リスト・辞書
#
# **遊び方**
#
# 1. 上から順にセルを見て、`...` の部分を自分のコードに置き換える
# 2. `Shift + Enter` で実行 → その場で ✅ / ❌ が出る
# 3. 詰まったら `hint('番号')`、どうしても無理なら `answer('番号')`
# 4. 最後に `score()` で進捗を見る
#
# 書き写し問題はなし。「自分で書く」問題だけ。

# %%
from drill import check, hint, answer, score
print('準備OK！ さっそく Q2-1 から')
# Out:
# 準備OK！ さっそく Q2-1 から

# %% [markdown]
# ## リスト：読書記録
#
# 1週間で読んだページ数。
#
# | 1日目 | 2日目 | 3日目 | 4日目 | 5日目 | 6日目 | 7日目 |
# |---|---|---|---|---|---|---|
# | 120 | 0 | 85 | 200 | 60 | 0 | 150 |

# %% [markdown]
# ### Q2-1  表のページ数をリスト `pages` に

# %%
pages = [120,0,85,200,60,0,150]

check('2-1', pages)
# Out:
# ✅ 2-1 正解！   第2章 1/18  █░░░░░░░░░░░░░░░░░░░
#    値: [120, 0, 85, 200, 60, 0, 150]  型: list
#    📖 模範解答: pages = [120, 0, 85, 200, 60, 0, 150]

# %% [markdown]
# ### Q2-2  記録した日数を `days` に

# %%
days = len(pages) #len関数！

check('2-2', days)
# Out:
# ✅ 2-2 正解！   第2章 2/18  ██░░░░░░░░░░░░░░░░░░
#    値: 7  型: int
#    📖 模範解答: days = len(pages)

# %% [markdown]
# ### Q2-3  合計ページ数を `total_pages` に

# %%
total_pages = sum(pages)

check('2-3', total_pages)
# Out:
# ✅ 2-3 正解！  🔥2連続   第2章 3/18  ███░░░░░░░░░░░░░░░░░
#    値: 615  型: int
#    📖 模範解答: total_pages = sum(pages)

# %% [markdown]
# ### Q2-4  一番読んだ日のページ数を `max_pages` に

# %%
max_pages = max(pages)

check('2-4', max_pages)
# Out:
# ✅ 2-4 正解！  🔥3連続   第2章 4/18  ████░░░░░░░░░░░░░░░░
#    値: 200  型: int
#    📖 模範解答: max_pages = max(pages)

# %% [markdown]
# ### Q2-5  一番少ない日のページ数を `min_pages` に

# %%
min_pages = min(pages)

check('2-5', min_pages)
# Out:
# ✅ 2-5 正解！  🔥4連続   第2章 5/18  █████░░░░░░░░░░░░░░░
#    値: 0  型: int
#    📖 模範解答: min_pages = min(pages)

# %% [markdown]
# ### Q2-6  5日目は本当は 65 ページだった。修正して、リスト全体を採点

# %%
pages = [120, 0, 85, 200, 60, 0, 150]

pages[4] = 65

check('2-6', pages)
# Out:
# ✅ 2-6 正解！  🔥5連続   第2章 6/18  ██████░░░░░░░░░░░░░░
#    値: [120, 0, 85, 200, 65, 0, 150]  型: list
#    📖 模範解答: pages[4] = 65

# %% [markdown]
# ## リスト：自分の点数

# %% [markdown]
# ### Q2-7  `[国語, 数学, 英語]` の順。数学の点数を `math_score` に

# %%
my_scores = [72, 95, 88]

math_score = my_scores[1]

check('2-7', math_score)
# Out:
# ✅ 2-7 正解！  🔥6連続   第2章 7/18  ███████░░░░░░░░░░░░░
#    値: 95  型: int
#    📖 模範解答: math_score = my_scores[1]

# %% [markdown]
# ### Q2-8  平均点を `my_average` に（`sum` と `len` を使う）

# %%
my_average = sum(my_scores) / len(my_scores)

check('2-8', my_average)
# Out:
# ✅ 2-8 正解！  🔥7連続   第2章 8/18  ████████░░░░░░░░░░░░
#    値: 85.0  型: float
#    📖 模範解答: my_average = sum(my_scores) / len(my_scores)

# %% [markdown]
# ## 二次元リスト：気温と時刻表

# %% [markdown]
# ### Q2-9  `[最低気温, 最高気温]` が曜日ごとに並んでいる。火曜の最高気温を `tue_max` に

# %%
temps = [
    [22, 28],  # 月
    [21, 30],  # 火
    [19, 25],  # 水
]

tue_max = temps[1][1]

check('2-9', tue_max)
# Out:
# ✅ 2-9 正解！   第2章 9/18  ██████████░░░░░░░░░░
#    値: 30  型: int
#    📖 模範解答: tue_max = temps[1][1]

# %% [markdown]
# ### Q2-10  電車の時刻表 `[時, 分]`。3本目の「分」を `third_minute` に

# %%
timetable = [
    [7, 15],
    [7, 32],
    [8, 5],
    [8, 20],
]

third_minute = timetable[2][1]

check('2-10', third_minute)
# Out:
# ✅ 2-10 正解！  🔥2連続   第2章 10/18  ███████████░░░░░░░░░
#    値: 5  型: int
#    📖 模範解答: third_minute = timetable[2][1]

# %% [markdown]
# ### Q2-11  水曜の `[最低, 最高]` をまるごと `wed_temps` に

# %%
wed_temps = temps[2]

check('2-11', wed_temps)
# Out:
# ✅ 2-11 正解！  🔥3連続   第2章 11/18  ████████████░░░░░░░░
#    値: [19, 25]  型: list
#    📖 模範解答: wed_temps = temps[2]

# %% [markdown]
# ## 辞書：カフェのメニュー

# %% [markdown]
# ### Q2-12  紅茶の値段を `tea_price` に

# %%
menu = {'コーヒー': 400, '紅茶': 350, 'ケーキ': 500}

tea_price = menu['紅茶']

check('2-12', tea_price)
# Out:
# ✅ 2-12 正解（クリア済み）   第2章 12/18  █████████████░░░░░░░
#    値: 350  型: int
#    📖 模範解答: tea_price = menu['紅茶']

# %% [markdown]
# ### Q2-13  ジュース 300円 を追加して、辞書全体を採点

# %%
menu['ジュース'] = 300

check('2-13', menu)
# Out:
# ✅ 2-13 正解！   第2章 13/18  ██████████████░░░░░░
#    値: {'コーヒー': 400, '紅茶': 350, 'ケーキ': 500, 'ジュース': 300}  型: dict
#    📖 模範解答: menu['ジュース'] = 300

# %% [markdown]
# ### Q2-14  店舗ごとのメニュー（ネスト）から、公園店の紅茶の値段を `park_tea` に

# %%
shops = {
    '駅前店': {'コーヒー': 400, '紅茶': 350},
    '公園店': {'コーヒー': 420, '紅茶': 360},
}

park_tea = shops['公園店']['紅茶']

check('2-14', park_tea)
# Out:
# ✅ 2-14 正解！   第2章 14/18  ███████████████░░░░░
#    値: 360  型: int
#    📖 模範解答: park_tea = shops['公園店']['紅茶']

# %% [markdown]
# ## 辞書：モンスター図鑑

# %%
# まずこのセルを実行（図鑑の定義）
monsters = {
    'm01': {'name': 'スライム',  'hp': 30,  'type': '水'},
    'm02': {'name': 'ゴブリン',  'hp': 55,  'type': '土'},
    'm03': {'name': 'ドラゴン',  'hp': 300, 'type': '火'},
}
print('図鑑準備OK')
# Out:
# 図鑑準備OK

# %% [markdown]
# ### Q2-15  `m02` の名前を `name` に

# %%
name = monsters['m02']['name']

check('2-15', name)
# Out:
# ✅ 2-15 正解！   第2章 15/18  ████████████████░░░░
#    値: 'ゴブリン'  型: str
#    📖 模範解答: name = monsters['m02']['name']

# %% [markdown]
# ### Q2-16  `m01` の hp を 35 に変更して、その hp を採点

# %%
monsters['m01']['hp'] = 35

check('2-16', monsters['m01']['hp'])
# Out:
# ✅ 2-16 正解！  🔥2連続   第2章 16/18  █████████████████░░░
#    値: 35  型: int
#    📖 模範解答: monsters['m01']['hp'] = 35

# %% [markdown]
# ### Q2-17  `m03` の情報（内側の辞書）をまるごと `dragon` に

# %%
dragon = monsters['m03']

check('2-17', dragon)
# Out:
# ✅ 2-17 正解！  🔥3連続   第2章 17/18  ██████████████████░░
#    値: {'name': 'ドラゴン', 'hp': 300, 'type': '火'}  型: dict
#    📖 模範解答: dragon = monsters['m03']

# %% [markdown]
# ### Q2-18  メニューの商品名だけのリスト `items` を作る（`.keys()` と `list()`）

# %%
menu = {'コーヒー': 400, '紅茶': 350, 'ケーキ': 500}

items = list(menu.keys())

check('2-18', items)
answer('2-18')
# Out:
# ✅ 2-18 正解！   第2章 18/18  ████████████████████
#    値: ['コーヒー', '紅茶', 'ケーキ']  型: list
#    📖 模範解答: items = list(menu.keys())
# 🎉 第2章 コンプリート！ 最長連続正解: 7
# 📖 2-18 解答例:
# items = list(menu.keys())

# %% [markdown]
# ---
# ## おわり
#
# 進捗を確認しよう。

# %%
score('2')
# Out:
# ...
# 第2章  18/18  ████████████████████
# 最長連続正解: 7
# ...
