# %% [markdown]
# # ドリル1：変数・演算子・データ型
#
# **遊び方**
#
# 1. 上から順にセルを見て、`...` の部分を自分のコードに置き換える
# 2. `Shift + Enter` で実行 → その場で ✅ / ❌ が出る
# 3. 詰まったら `hint('番号')`、どうしても無理なら `answer('番号')`
# 4. 最後に `score()` で進捗を見る
#
# 書き写し問題はなし。「自分で書く」問題だけ。

# %%
from drill import check, hint, answer, score
print('準備OK！ さっそく Q1-1 から')
# Out:
# 準備OK！ さっそく Q1-1 から

# %% [markdown]
# ## 変数

# %% [markdown]
# ### Q1-1  変数 `player` に文字列 `'koichi'` を代入

# %%
player = 'koichi'

check('1-1', player)
# Out:
# ✅ 1-1 正解！  🔥3連続   第1章 3/30  ██░░░░░░░░░░░░░░░░░░
#    値: 'koichi'  型: str

# %% [markdown]
# ### Q1-2  `level` は今 1。レベルアップして 2 を再代入（上書き）

# %%
level = 1

level = 2

check('1-2', level)
# Out:
# ✅ 1-2 正解！  🔥4連続   第1章 4/30  ██░░░░░░░░░░░░░░░░░░
#    値: 2  型: int

# %% [markdown]
# ## 算術演算子

# %% [markdown]
# ### Q1-3  `7 × 6` を `result` に

# %%
result = 7 * 6

check('1-3', result)
# Out:
# ✅ 1-3 正解！  🔥5連続   第1章 5/30  ███░░░░░░░░░░░░░░░░░
#    値: 42  型: int

# %% [markdown]
# ### Q1-4  1年は365日。何週間あるか（**整数部分**）を `weeks` に

# %%
weeks = 52 #しらぬ

check('1-4', weeks)
# Out:
# ✅ 1-4 正解！  🔥6連続   第1章 6/30  ████░░░░░░░░░░░░░░░░
#    値: 52  型: int

# %% [markdown]
# ### Q1-5  365日を7で割った**余り**を `rest` に

# %%
rest = 365 % 7

check('1-5', rest)
# Out:
# ✅ 1-5 正解！  🔥7連続   第1章 7/30  ████░░░░░░░░░░░░░░░░
#    値: 1  型: int

# %% [markdown]
# ### Q1-6  `5 の 2 乗` を `result` に

# %%
result = 5 ** 2

check('1-6', result)
# Out:
# ✅ 1-6 正解！  🔥8連続   第1章 8/30  █████░░░░░░░░░░░░░░░
#    値: 25  型: int

# %% [markdown]
# ## 予想クイズ：演算子の優先度
#
# 実行せずに結果を予想して、数字を書く。

# %% [markdown]
# ### Q1-7
# ```python
# 10 - 2 * 3
# ```

# %%
prediction = 10 - 2 * 3

check('1-7', prediction)
# Out:
# ✅ 1-7 正解！  🔥9連続   第1章 9/30  ██████░░░░░░░░░░░░░░
#    値: 4  型: int

# %% [markdown]
# ### Q1-8
# ```python
# (10 - 2) * 3
# ```

# %%
prediction = (10 - 2) * 3

check('1-8', prediction)
# Out:
# ✅ 1-8 正解！  🔥10連続   第1章 10/30  ██████░░░░░░░░░░░░░░
#    値: 24  型: int

# %% [markdown]
# ### Q1-9
# ```python
# 3 * 2 ** 2
# ```

# %%
prediction = 3 * 2 ** 2

check('1-9', prediction)
# Out:
# ✅ 1-9 正解！  🔥11連続   第1章 11/30  ███████░░░░░░░░░░░░░
#    値: 12  型: int

# %% [markdown]
# ### Q1-10
# ```python
# 100 // 3 * 3
# ```

# %%
prediction = 100 // 3 * 3

check('1-10', prediction)
# Out:
# ✅ 1-10 正解！  🔥12連続   第1章 12/30  ████████░░░░░░░░░░░░
#    値: 99  型: int

# %% [markdown]
# ## 文章題：スーパーで買い物
#
# 卵1パック 250円、牛乳 180円、食パン 160円。

# %% [markdown]
# ### Q1-11  卵を2パック買ったときの金額を `eggs_price` に

# %%
egg = 250
milk = 180
bread = 160

eggs_price = egg * 2

check('1-11', eggs_price)
# Out:
# ✅ 1-11 正解！  🔥13連続   第1章 13/30  ████████░░░░░░░░░░░░
#    値: 500  型: int

# %% [markdown]
# ### Q1-12  牛乳3本 + 食パン2斤の金額を `drink_bread` に

# %%
drink_bread = milk * 3 + bread * 2

check('1-12', drink_bread)
# Out:
# ✅ 1-12 正解！  🔥14連続   第1章 14/30  █████████░░░░░░░░░░░
#    値: 860  型: int

# %% [markdown]
# ### Q1-13  3つを1個ずつ買って、消費税8%（= 1.08倍）を掛けた金額を `total_with_tax` に

# %%
total_with_tax = (egg + milk + bread) * 1.08

check('1-13', total_with_tax)
# Out:
# ✅ 1-13 正解！  🔥15連続   第1章 15/30  ██████████░░░░░░░░░░
#    値: 637.2  型: float

# %% [markdown]
# ## 文章題：旅行の割り勘
#
# 4人で旅行。ホテル 24,000円、レンタカー 9,600円。

# %% [markdown]
# ### Q1-14  ホテルとレンタカーの合計を `total` に

# %%
hotel = 24000
rental_car = 9600
people = 4

total = hotel + rental_car

check('1-14', total)
# Out:
# ✅ 1-14 正解！  🔥16連続   第1章 16/30  ██████████░░░░░░░░░░
#    値: 33600  型: int

# %% [markdown]
# ### Q1-15  1人あたりの負担額を `per_person` に

# %%
per_person = total / 4

check('1-15', per_person)
# Out:
# ✅ 1-15 正解！  🔥17連続   第1章 17/30  ███████████░░░░░░░░░
#    値: 8400.0  型: float

# %% [markdown]
# ### Q1-16  ガソリンは 1L 170円で 30L 入れた。ガソリン代の1人分を `gas_per_person` に

# %%
gas_price = 170
liters = 30

gas_per_person = gas_price * liters / 4

check('1-16', gas_per_person)
# Out:
# ✅ 1-16 正解！  🔥18連続   第1章 18/30  ████████████░░░░░░░░
#    値: 1275.0  型: float

# %% [markdown]
# ## データ型

# %% [markdown]
# ### Q1-17  文字列 `'42'` を整数に変換して `x` に入れ直し、`type_name` に型の名前を入れる（ヒント: `type(x).__name__`）

# %%
x = '42'
x = int(x)
type_name = type(x).__name__

check('1-17', type_name)
# Out:
# ✅ 1-17 正解！  🔥19連続   第1章 19/30  ████████████░░░░░░░░
#    値: 'int'  型: str

# %% [markdown]
# ### Q1-18  【予想】`int(9.99)` はいくつ？

# %%
prediction = int(9.99)

check('1-18', prediction)
# Out:
# ✅ 1-18 正解（クリア済み）  🔥19連続   第1章 19/30  ████████████░░░░░░░░
#    値: 9  型: int

# %% [markdown]
# ### Q1-19  【予想】
# ```python
# int('3') * float('1.5')
# ```

# %%
prediction = int('3') * float('1.5')

check('1-19', prediction)
# Out:
# ✅ 1-19 正解（クリア済み）  🔥19連続   第1章 19/30  ████████████░░░░░░░░
#    値: 4.5  型: float

# %% [markdown]
# ### Q1-20  【予想】`str(7) + str(7)` は？（数値か文字列かに注意）

# %%
prediction = str(7) + str(7)

check('1-20', prediction)
# Out:
# ✅ 1-20 正解！  🔥20連続   第1章 20/30  █████████████░░░░░░░
#    値: '77'  型: str

# %% [markdown]
# ### Q1-21  【バグ修正】`age + 1` はエラーになる。来年の年齢を **数値で** `next_age` に

# %%
age = '25'

next_age = int(age) + 1

check('1-21', next_age)
# Out:
# ✅ 1-21 正解！  🔥21連続   第1章 21/30  ██████████████░░░░░░
#    値: 26  型: int

# %% [markdown]
# ### Q1-22  【予想】`bool('')`（空の文字列）は True か False か

# %%
prediction = bool('') # 空だとFalse

check('1-22', prediction)
# Out:
# ✅ 1-22 正解！  🔥22連続   第1章 22/30  ██████████████░░░░░░
#    値: False  型: bool

# %% [markdown]
# ### Q1-23  姓と名の間に半角スペースを入れて `'山田 太郎'` を `full_name` に

# %%
first = '山田'
last = '太郎'

full_name = first + ' ' + last

check('1-23', full_name)
# Out:
# ✅ 1-23 正解！   第1章 23/30  ███████████████░░░░░
#    値: '山田 太郎'  型: str

# %% [markdown]
# ### Q1-24  f-string で `'りんごを3個買って360円'` を作り `text` に

# %%
item = 'りんご'
qty = 3
price = 360

text = f'{item}を{qty}個買って{price}円' #f

check('1-24', text)
# Out:
# ✅ 1-24 正解！  🔥2連続   第1章 24/30  ████████████████░░░░
#    値: 'りんごを3個買って360円'  型: str

# %% [markdown]
# ### Q1-25  残高 1200円、値段 1500円。**買えるなら True、買えないなら False** になる式を `can_buy` に

# %%
balance = 1200
price = 1500

can_buy = balance >= price

check('1-25', can_buy)
answer('1-25')
# Out:
# ✅ 1-25 正解（クリア済み）  🔥3連続   第1章 25/30  ████████████████░░░░
#    値: False  型: bool
# 📖 1-25 解答例:
# can_buy = balance >= price

# %% [markdown]
# ## 総合：ゲームのスコア
#
# ステージ1: 1200点、ステージ2: 950点、ステージ3: 1830点。

# %% [markdown]
# ### Q1-26  3ステージの合計を `total` に

# %%
stage1 = 1200
stage2 = 950
stage3 = 1830

total = stage1 + stage2 + stage3

check('1-26', total)
# Out:
# ✅ 1-26 正解（クリア済み）  🔥4連続   第1章 26/30  █████████████████░░░
#    値: 3980  型: int
# 📖 1-26 解答例:
# total = stage1 + stage2 + stage3

# %% [markdown]
# ### Q1-27  平均を `average` に

# %%
average = total / 3

check('1-27', average)
# Out:
# ✅ 1-27 正解！  🔥5連続   第1章 27/30  ██████████████████░░
#    値: 1326.6666666666667  型: float

# %% [markdown]
# ### Q1-28  `'平均スコアは1326.7点'` のように**小数1桁**で表示する文字列を `text` に（ヒント: `{average:.1f}`）

# %%
text = f'平均スコアは{average:.1f}点'

check('1-28', text)
# Out:
# ✅ 1-28 正解！   第1章 28/30  ██████████████████░░
#    値: '平均スコアは1326.7点'  型: str

# %% [markdown]
# ## 総合：ランニング記録
#
# | 月 | 火 | 水 | 木 | 金 |
# |---|---|---|---|---|
# | 3.5 km | 0 km | 5 km | 2.5 km | 4 km |
#
# 週の目標は 15 km。

# %% [markdown]
# ### Q1-29  各曜日を変数にして、合計を `total_km` に

# %%
mon = 3.5
tue = 0
wed = 5
thu = 2.5
fri = 4

total_km = mon + tue + wed + thu + fri

check('1-29', total_km)
# Out:
# ✅ 1-29 正解！  🔥2連続   第1章 29/30  ███████████████████░
#    値: 15.0  型: float

# %% [markdown]
# ### Q1-30  目標を達成したか を `achieved` に（bool）

# %%
goal = 15

achieved = goal >= 15

check('1-30', achieved)
# Out:
# ✅ 1-30 正解！  🔥3連続   第1章 30/30  ████████████████████
#    値: True  型: bool
# 🎉 第1章 コンプリート！ 最長連続正解: 22

# %% [markdown]
# ---
# ## おわり
#
# 進捗を確認しよう。

# %%
score('1')
# Out:
# ...
# 第1章  30/30  ████████████████████
# 最長連続正解: 22
# ...
